# %%
import json
import os
import pandas as pd

# %%
def combine_games(csv_list):
    result = []
    for x in csv_list:
        df = pd.read_csv("./HexGate/"+x)
        result.append(df)
    return result

# %%
x = combine_games(os.listdir("./HexGate/"))

final_dataset = pd.concat(x)

final_dataset.to_csv("HexGate_Archive.csv", index=False)

# %%
with open("./summoners_dictionary.json", mode="r", encoding="utf-8") as file:
    summoner_dict = json.load(file)

with open("./item_dictionary.json", mode="r", encoding="utf-8") as file:
    item_dict = json.load(file)

with open("./rune_dictionary.json", mode="r", encoding="utf-8") as file:
    rune_dict = json.load(file)

with open("./champion_dictionary.json", mode="r", encoding="utf-8") as file:
    champ_dict = json.load(file)

df = pd.read_csv("./HexGate_Archive.csv")

df = df.dropna()
df = df.replace(summoner_dict)
df = df.replace(item_dict)
df = df.replace(rune_dict)
df = df.replace(champ_dict)
# Out:
# C:\Users\tinay\AppData\Local\Temp\ipykernel_11936\1941487926.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(summoner_dict)
# C:\Users\tinay\AppData\Local\Temp\ipykernel_11936\1941487926.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(item_dict)
# C:\Users\tinay\AppData\Local\Temp\ipykernel_11936\1941487926.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(rune_dict)
# C:\Users\tinay\AppData\Local\Temp\ipykernel_11936\1941487926.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(champ_dict)

# %%
df.to_csv("HexGate_Final_Version.csv", index=False)

# %%
import pandas as pd

# Cleaning the final dataset and making sure it works

final = pd.read_csv("./HexGate_Final_Version.csv")

# %%
game_ids = []

for x in range(len(final)):
    x = str(f"EUW_{x:05d}")
    game_ids.append(x)

final.insert(1,"GAME_NUMBER",game_ids)

final = final.drop('GAME_ID', axis=1)

# %%
final.to_csv("HexGate.csv", index=False)
