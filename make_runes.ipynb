# %%
import pandas as pd
import numpy as np
import json

with open("./en_US/item.json", mode="r", encoding="utf-8") as file:
    items = json.load(file)

item_id_list = []

for x in items['data']:
    item_id_list.append(int(x))

print(item_id_list)
# Out:
# [1001, 1004, 1006, 1011, 1018, 1026, 1027, 1028, 1029, 1031, 1033, 1035, 1036, 1037, 1038, 1039, 1040, 1042, 1043, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1082, 1083, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 126697, 1500, 1501, 1502, 1503, 1504, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 2003, 2010, 2015, 2019, 2020, 2021, 2022, 2031, 2033, 2049, 2050, 2051, 2052, 2055, 2056, 2065, 2138, 2139, 2140, 2141, 2142, 2143, 2144, 2145, 2150, 2151, 2152, 220000, 220001, 220002, 220003, 220004, 220005, 220006, 220007, 221011, 221026, 221031, 221038, 221043, 221053, 221057, 221058, 222022, 222051, 222065, 222141, 222502, 222503, 222504, 223001, 223002, 223003, 223004, 223005, 223006, 223009, 223011, 223020, 223026, 223031, 223032, 223033, 223036, 223039, 223040, 223042, 223046, 223047, 223050, 223053, 223057, 223065, 223067, 223068, 223071, 223072, 223073, 223074, 223075, 223078, 223084, 223085, 223087, 223089, 223091, 223094, 223095, 223100, 2
# ...

# %%
item_dictionary = [(1000, 'No_Item')]

for x in item_id_list:
    item_dictionary.append((x, items['data'][str(x)]['name']))

new_item_dictionary = dict(item_dictionary)

# %%
with open("item_dictionary.json", mode="w") as file:
    json.dump(new_item_dictionary, file, indent=4)
